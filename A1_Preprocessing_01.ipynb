# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/manipulation/car_price_prediction.csv")
df.head()
#df.describe(include='all')
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Remove ID Column

# %%
df.drop(columns=['ID'],inplace=True)
df.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467     -        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Manufacturer Mapping

# %%
unique_manufacturer = df["Manufacturer"].unique()

# Use of AI:
# Why? -> new to python. Before mainly java (spring) and cpp
# Prompt: "in python i have a list of names which I want to put into a dictionary with an associated int value starting from 1 (so e.g. Ford - 1, Audi - 2 , Mercedes - 3 ,....)How do I do that"
# Result (with small adjustment):
manufacturer_result = {unique: i+1 for i, unique in enumerate(unique_manufacturer)}
print(manufacturer_result)

# Replace value in dataframe with according integer from the dictionary
df.replace(manufacturer_result,inplace=True)
df.head()
# Out:
# {'LEXUS': 1, 'CHEVROLET': 2, 'HONDA': 3, 'FORD': 4, 'HYUNDAI': 5, 'TOYOTA': 6, 'MERCEDES-BENZ': 7, 'OPEL': 8, 'PORSCHE': 9, 'BMW': 10, 'JEEP': 11, 'VOLKSWAGEN': 12, 'AUDI': 13, 'RENAULT': 14, 'NISSAN': 15, 'SUBARU': 16, 'DAEWOO': 17, 'KIA': 18, 'MITSUBISHI': 19, 'SSANGYONG': 20, 'MAZDA': 21, 'GMC': 22, 'FIAT': 23, 'INFINITI': 24, 'ALFA ROMEO': 25, 'SUZUKI': 26, 'ACURA': 27, 'LINCOLN': 28, 'VAZ': 29, 'GAZ': 30, 'CITROEN': 31, 'LAND ROVER': 32, 'MINI': 33, 'DODGE': 34, 'CHRYSLER': 35, 'JAGUAR': 36, 'ISUZU': 37, 'SKODA': 38, 'DAIHATSU': 39, 'BUICK': 40, 'TESLA': 41, 'CADILLAC': 42, 'PEUGEOT': 43, 'BENTLEY': 44, 'VOLVO': 45, 'სხვა': 46, 'HAVAL': 47, 'HUMMER': 48, 'SCION': 49, 'UAZ': 50, 'MERCURY': 51, 'ZAZ': 52, 'ROVER': 53, 'SEAT': 54, 'LANCIA': 55, 'MOSKVICH': 56, 'MASERATI': 57, 'FERRARI': 58, 'SAAB': 59, 'LAMBORGHINI': 60, 'ROLLS-ROYCE': 61, 'PONTIAC': 62, 'SATURN': 63, 'ASTON MARTIN': 64, 'GREATWALL': 65}
# /tmp/ipykernel_1887/3238047406.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(manufacturer_result,inplace=True)
#    Price  Levy  Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399             1   RX 450        2010       Jeep              Yes
# 1  16621  1018             2  Equinox        2011       Jeep               No
# 2   8467     -             3      FIT        2006  Hatchback               No
# 3   3607   862             4   Escape        2011       Jeep              Yes
# 4  11726   446             3      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Model Mapping

# %%
unique_model = df["Model"].unique()
print(len(unique_model))
model_result = {unique: i+1 for i, unique in enumerate(unique_model)}
print(model_result)

df.replace(model_result,inplace=True)
df.head()
# Out:
# 1590
# {'RX 450': 1, 'Equinox': 2, 'FIT': 3, 'Escape': 4, 'Santa FE': 5, 'Prius': 6, 'Sonata': 7, 'Camry': 8, 'RX 350': 9, 'E 350': 10, 'Transit': 11, 'Vectra': 12, 'CHR': 13, 'Elantra': 14, 'RX 400': 15, 'E 220': 16, 'GX 470': 17, 'Highlander': 18, 'Vito': 19, 'Cayenne': 20, 'X5': 21, 'Grand Cherokee': 22, 'CHR Limited': 23, 'H1': 24, 'Jetta': 25, 'Tacoma': 26, 'Prius C': 27, 'Aqua': 28, 'Escape Hybrid': 29, 'Civic': 30, 'Q7': 31, 'Megane 1.5CDI': 32, 'E 300': 33, 'Q5': 34, 'C 180': 35, 'GLA 250': 36, 'Juke': 37, '535': 38, 'Cruze LT': 39, 'Fusion': 40, 'VOXY': 41, 'A 160': 42, 'Tucson': 43, 'Vitz': 44, 'Captiva': 45, 'Mustang': 46, 'ML 350': 47, 'Yaris': 48, 'Cr-v': 49, 'Cruze': 50, 'Orlando': 51, 'GL 63 AMG': 52, '520 Vanos': 53, 'Forester': 54, 'Lacetti': 55, '428 Sport Line': 56, 'Patrol': 57, 'E 320': 58, 'Genesis': 59, '911': 60, 'GX 460': 61, 'Sprinter': 62, 'Focus SE': 63, 'Picanto': 64, '328': 65, 'Explorer': 66, 'Airtrek': 67, 'E 500 AMG': 68, 'Lancer': 69, 'Korando': 70, 'Clio': 71, '616': 72, 'C 220': 73, 'Serena': 74, 'Maxima': 75, 'RAV 4': 76, 'Pajero': 77, 'Volt': 78, 'TERRAIN': 79, '208': 80, 'Hr-v EX': 81, '500': 82, 'Legacy': 83, 'Elantra sport limited': 84, 'Sienna': 85, 'A 170': 86, 'NX 300': 87, 'REXTON': 88, 'Carnival grand': 89, 'QX60': 90, 'Passat': 91, 'E 240 E 240': 92, '1000': 93, '50': 94, 'C 250': 95, 'Vitz funkargo': 96, '325': 97, 'A6': 98, 'Pathfinder': 99, 'Delica': 100, 'Golf': 101, 'Vaneo': 102, 'Camry Se': 103, 'Patrol Y60': 104, 'A7': 105, 'I30': 106, 'Altima': 107, '147': 108, 'Grand Vitara': 109, 'CT 200h': 110, 'Panamera': 111, 'Veloster': 112, 'RAV 4 XLE Sport': 113, 'Sienta': 114, 'CLS 550': 115, 'Avalanche': 116, 'Avalon LIMITED': 117, 'Cerato K3': 118, 'CX-7': 119, 'Astra G': 120, 'Ist': 121, 'Corolla': 122, 'Rogue': 123, 'MPV': 124, '530': 125, 'GS 350': 126, 'Sharan': 127, 'Tiida': 128, 'C 300': 129, 'Actyon': 130, 'Tundra': 131, 'Elgrand': 132, 'C 350': 133, 'CLS 500': 134, 'S 350': 135, 'RAV 4 Le': 136, 'Zafira': 137, 'Vectra b': 138, 'C 200': 139, 'Astra': 140, '323': 141, 'E 350 ამგ': 142, 'CLK 320': 143, 'Avalon': 144, 'ML 250': 145, '330': 146, 'A7 Prestige': 147, 'Colt Lancer': 148, '318': 149, 'Outlander': 150, 'Camry SE': 151, 'E 200': 152, 'GLE 350': 153, 'Malibu': 154, 'TL': 155, 'Insight': 156, 'Stream': 157, 'I': 158, 'GTI': 159, 'Colt': 160, 'Pajero Mini': 161, 'C-MAX': 162, '750': 163, 'RAV 4 s p o r t': 164, 'E 250': 165, 'Outback': 166, 'GLC 300': 167, 'Navigator': 168, 'Fusion Titanium': 169, 'Jimny': 170, 'Aveo': 171, 'X6': 172, 'Aqua S': 173, '1111': 174, 'NX 200': 175, '32214': 176, 'Laguna': 177, 'Optima': 178, 'Shuttle': 179, 'C 240': 180, 'Land Cruiser Prado': 181, '328 Xdrive': 182, 'E 240': 183, 'Taurus': 184, 'Twingo': 185, '535 M PAKET': 186, 'S 500 long': 187, '520': 188, '525': 189, 'A4 premium': 190, 'Galaxy': 191, 'Kizashi': 192, 'Golf 4': 193, 'Element': 194, 'C1': 195, 'X-Trail': 196, 'RIO': 197, 'Discovery': 198, 'Vento': 199, 'C 200 2.0': 200, 'M6': 201, 'ML 550 4.7': 202, 'Corolla IM': 203, 'CLK 240': 204, 'Fiesta': 205, 'Cooper': 206, 'Combo': 207, 'Challenger': 208, 'RX 300': 209, 'A4': 210, '320': 211, 'RX 400 HYBRID': 212, 'Corolla verso': 213, 'Pajero IO': 214, '528 i': 215, 'Odyssey': 216, 'L 200': 217, 'Insight EX': 218, 'Fiesta 1.6': 219, 'Focus': 220, 'Teana': 221, 'Matiz': 222, 'Mazda 3': 223, 'Corsa': 224, 'Scenic': 225, 'Spark': 226, 'March': 227, 'Wrangler': 228, 'HS 250h Hybrid': 229, 'Journey': 230, 'Sonata SPORT': 231, 'Elantra SE': 232, 'Rogue Sport': 233, 'Auris': 234, 'E 270': 235, 'FJ Cruiser': 236, 'ES 350': 237, 'M3': 238, 'Impala': 239, 'SOUL': 240, 'S 350 W2222': 241, '500C Lounge': 242, 'X-Terra': 243, 'Montero': 244, 'Cruze ltz': 245, 'X5 x5': 246, 'Ipsum': 247, 'Countryman': 248, 'Corolla 04': 249, 'A 190': 250, 'SLK 230': 251, 'Rogue SL': 252, 'Q3': 253, 'Accent': 254, 'Frontier': 255, 'Grandeur': 256, 'Stella': 257, 'Hr-v': 258, 'Prius 2014': 259, 'Dart Limited': 260, 'CX-9': 261, '200': 262, 'Accord': 263, 'XF': 264, 'IS  ...
# /tmp/ipykernel_1887/2957657005.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(model_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year   Category Leather interior  \
# 0  13328  1399             1      1        2010       Jeep              Yes
# 1  16621  1018             2      2        2011       Jeep               No
# 2   8467     -             3      3        2006  Hatchback               No
# 3   3607   862             4      4        2011       Jeep              Yes
# 4  11726   446             3      3        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Category Mapping

# %%
unique_category = df["Category"].unique()
print(len(unique_category))
category_result = {unique: i+1 for i, unique in enumerate(unique_category)}
print(category_result)

df.replace(category_result,inplace=True)
df.head()
# Out:
# 11
# {'Jeep': 1, 'Hatchback': 2, 'Sedan': 3, 'Microbus': 4, 'Goods wagon': 5, 'Universal': 6, 'Coupe': 7, 'Minivan': 8, 'Cabriolet': 9, 'Limousine': 10, 'Pickup': 11}
# /tmp/ipykernel_1887/3166455121.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(category_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category Leather interior  \
# 0  13328  1399             1      1        2010         1              Yes
# 1  16621  1018             2      2        2011         1               No
# 2   8467     -             3      3        2006         2               No
# 3   3607   862             4      4        2011         1              Yes
# 4  11726   446             3      3        2014         2              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Interior Boolean Mapping
# 1 = yes, 0 = no

# %%
bool_mapping = {"Yes":1,"No":0}
df.replace(bool_mapping,inplace=True)
df.head()
# Out:
# /tmp/ipykernel_1887/1814615233.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(bool_mapping,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Fuel Type Mapping

# %%
unique_fuel = df["Fuel type"].unique()
print(len(unique_fuel))
fuel_result = {unique: i+1 for i, unique in enumerate(unique_fuel)}
print(fuel_result)

df.replace(fuel_result,inplace=True)
df.head()
# Out:
# 7
# {'Hybrid': 1, 'Petrol': 2, 'Diesel': 3, 'CNG': 4, 'Plug-in Hybrid': 5, 'LPG': 6, 'Hydrogen': 7}
# /tmp/ipykernel_1887/3351001341.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(fuel_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0          1           3.5  186005 km        6.0     Automatic          4x4
# 1          2             3  192000 km        6.0     Tiptronic          4x4
# 2          2           1.3  200000 km        4.0      Variator        Front
# 3          1           2.5  168966 km        4.0     Automatic          4x4
# 4          2           1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %%
df.describe()
# Out:
#               Price  Manufacturer         Model    Prod. year      Category  \
# count  1.730600e+04  17306.000000  17306.000000  17306.000000  17306.000000
# mean   1.744961e+04      8.010863    143.896279   2011.056974      2.636889
# std    2.006192e+05      6.889905    262.065702      5.636826      1.685642
# min    1.000000e+00      1.000000      1.000000   1939.000000      1.000000
# 25%    4.547000e+03      5.000000      8.000000   2010.000000      1.000000
# 50%    1.227650e+04      6.000000     40.000000   2012.000000      3.000000
# 75%    2.110300e+04      8.000000    151.000000   2015.000000      3.000000
# max    2.630750e+07     65.000000   1590.000000   2020.000000     11.000000
#
#        Leather interior     Fuel type  Engine volume     Cylinders  \
# count      17306.000000  17306.000000   17306.000000  17306.000000
# mean           0.740899      2.251647       2.376667      4.568242
# std            0.438154      1.137399       6.174598      1.175546
# min            0.000000      1.000000       0.000000      1.000000
# 25%            0.000000      2.000000       1.800000      4.000000
# 50%            1.000000      2.000000       2.000000      4.000000
# 75%            1.000000      3.000000       2.500000      4.000000
# max            1.000000      7.000000     571.000000     16.000000
#
#             Airbags
# count  17306.000000
# mean       6.493702
# std        4.328332
# min        0.000000
# 25%        4.000000
# 50%        4.000000
# 75%       12.000000
# max       16.000000

# %% [markdown]
# Problem: column Engine Volume doesnt show up in df.describe() even though there should only be numeric values inside
# Solution: Search for != Integers and delete rows / adjust data inside the cells

# %%
# source: https://www.geeksforgeeks.org/python/check-for-nan-in-pandas-dataframe/
#print(df["Engine volume"].isnull().sum())
# => no Null values

#print(df["Engine volume"].dtypes)
#=> alles object datatypes

#dataframe to numeric casten, everything else is gonna be NaN and remove them from the dataset
# source: docs https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html
df["Engine volume"] = pd.to_numeric(df["Engine volume"],errors="coerce")
# result: ~1700 rows => too much for manual adjustment => remove rows 
df.dropna(how='any',axis=0,inplace=True)
df["Engine volume"].describe()
# Out:
# count    17306.000000
# mean         2.376667
# std          6.174598
# min          0.000000
# 25%          1.800000
# 50%          2.000000
# 75%          2.500000
# max        571.000000
# Name: Engine volume, dtype: float64

# %%
df.head()
# Out:
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0          1            3.5  186005 km        6.0     Automatic          4x4
# 1          2            3.0  192000 km        6.0     Tiptronic          4x4
# 2          2            1.3  200000 km        4.0      Variator        Front
# 3          1            2.5  168966 km        4.0     Automatic          4x4
# 4          2            1.3   91901 km        4.0     Automatic        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Remove "km" suffix from Mileage column

# %%
#this throws an error, now that it isnt an object anymore
#df["Mileage"] = df["Mileage"].str.replace(" km", "")

df.describe()
print(df["Mileage"].dtype)
#problem: column mileage still not getting detected as numeric
df["Mileage"] = pd.to_numeric(df["Mileage"],errors="coerce")
df.describe()
# Out:
# int64
#               Price  Manufacturer         Model    Prod. year      Category  \
# count  1.730600e+04  17306.000000  17306.000000  17306.000000  17306.000000
# mean   1.744961e+04      8.010863    143.896279   2011.056974      2.636889
# std    2.006192e+05      6.889905    262.065702      5.636826      1.685642
# min    1.000000e+00      1.000000      1.000000   1939.000000      1.000000
# 25%    4.547000e+03      5.000000      8.000000   2010.000000      1.000000
# 50%    1.227650e+04      6.000000     40.000000   2012.000000      3.000000
# 75%    2.110300e+04      8.000000    151.000000   2015.000000      3.000000
# max    2.630750e+07     65.000000   1590.000000   2020.000000     11.000000
#
#        Leather interior     Fuel type  Engine volume       Mileage  \
# count      17306.000000  17306.000000   17306.000000  1.730600e+04
# mean           0.740899      2.251647       2.376667  1.556669e+06
# std            0.438154      1.137399       6.174598  4.834610e+07
# min            0.000000      1.000000       0.000000  0.000000e+00
# 25%            0.000000      2.000000       1.800000  7.099400e+04
# 50%            1.000000      2.000000       2.000000  1.260000e+05
# 75%            1.000000      3.000000       2.500000  1.881940e+05
# max            1.000000      7.000000     571.000000  2.147484e+09
#
#           Cylinders       Airbags
# count  17306.000000  17306.000000
# mean       4.568242      6.493702
# std        1.175546      4.328332
# min        1.000000      0.000000
# 25%        4.000000      4.000000
# 50%        4.000000      4.000000
# 75%        4.000000     12.000000
# max       16.000000     16.000000

# %% [markdown]
# ## Gear box type mapping

# %%
unique_gear = df["Gear box type"].unique()
print(len(unique_gear))
gear_result = {unique: i+1 for i, unique in enumerate(unique_gear)}
print(gear_result)

df.replace(gear_result,inplace=True)
df.head()
# Out:
# 4
# {np.int64(1): 1, np.int64(2): 2, np.int64(3): 3, np.int64(4): 4}
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume  Mileage  Cylinders  Gear box type Drive wheels  \
# 0          1            3.5   186005        6.0              1          4x4
# 1          2            3.0   192000        6.0              2          4x4
# 2          2            1.3   200000        4.0              3        Front
# 3          1            2.5   168966        4.0              1          4x4
# 4          2            1.3    91901        4.0              1        Front
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Drive Wheels Mapping

# %%
unique_wheels = df["Drive wheels"].unique()
print(len(unique_wheels))
wheels_result = {unique: i+1 for i, unique in enumerate(unique_wheels)}
print(wheels_result)

df.replace(wheels_result,inplace=True)
df.head()
# Out:
# 3
# {'4x4': 1, 'Front': 2, 'Rear': 3}
# /tmp/ipykernel_1887/1985282800.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(wheels_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume  Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1            3.5   186005        6.0              1             1
# 1          2            3.0   192000        6.0              2             1
# 2          2            1.3   200000        4.0              3             2
# 3          1            2.5   168966        4.0              1             1
# 4          2            1.3    91901        4.0              1             2
#
#     Doors             Wheel   Color  Airbags
# 0  04-May        Left wheel  Silver       12
# 1  04-May        Left wheel   Black        8
# 2  04-May  Right-hand drive   Black        2
# 3  04-May        Left wheel   White        0
# 4  04-May        Left wheel  Silver        4

# %% [markdown]
# ## Doors Mapping

# %%
unique_doors = df["Doors"].unique()
print(len(unique_doors))
doors_result = {unique: i+1 for i, unique in enumerate(unique_doors)}
print(doors_result)

df.replace(doors_result,inplace=True)
df.head()
# Out:
# 3
# {'04-May': 1, '02-Mar': 2, '>5': 3}
# /tmp/ipykernel_1887/2406772073.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(doors_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume  Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1            3.5   186005        6.0              1             1
# 1          2            3.0   192000        6.0              2             1
# 2          2            1.3   200000        4.0              3             2
# 3          1            2.5   168966        4.0              1             1
# 4          2            1.3    91901        4.0              1             2
#
#    Doors             Wheel   Color  Airbags
# 0      1        Left wheel  Silver       12
# 1      1        Left wheel   Black        8
# 2      1  Right-hand drive   Black        2
# 3      1        Left wheel   White        0
# 4      1        Left wheel  Silver        4

# %% [markdown]
# ## Wheel Mapping

# %%
unique_wheel = df["Wheel"].unique()
print(len(unique_wheel))
wheel_result = {unique: i+1 for i, unique in enumerate(unique_wheel)}
print(wheel_result)

df.replace(wheel_result,inplace=True)
df.head()
# Out:
# 2
# {'Left wheel': 1, 'Right-hand drive': 2}
# /tmp/ipykernel_1887/1493574570.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(wheel_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume  Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1            3.5   186005        6.0              1             1
# 1          2            3.0   192000        6.0              2             1
# 2          2            1.3   200000        4.0              3             2
# 3          1            2.5   168966        4.0              1             1
# 4          2            1.3    91901        4.0              1             2
#
#    Doors  Wheel   Color  Airbags
# 0      1      1  Silver       12
# 1      1      1   Black        8
# 2      1      2   Black        2
# 3      1      1   White        0
# 4      1      1  Silver        4

# %% [markdown]
# ## Color Mapping

# %%
unique_color = df["Color"].unique()
print(len(unique_color))
color_result = {unique: i+1 for i, unique in enumerate(unique_color)}
print(color_result)

df.replace(color_result,inplace=True)
df.head()
# Out:
# 16
# {'Silver': 1, 'Black': 2, 'White': 3, 'Grey': 4, 'Blue': 5, 'Green': 6, 'Red': 7, 'Sky blue': 8, 'Orange': 9, 'Yellow': 10, 'Brown': 11, 'Golden': 12, 'Beige': 13, 'Carnelian red': 14, 'Purple': 15, 'Pink': 16}
# /tmp/ipykernel_1887/277343412.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(color_result,inplace=True)
#    Price  Levy  Manufacturer  Model  Prod. year  Category  Leather interior  \
# 0  13328  1399             1      1        2010         1                 1
# 1  16621  1018             2      2        2011         1                 0
# 2   8467     -             3      3        2006         2                 0
# 3   3607   862             4      4        2011         1                 1
# 4  11726   446             3      3        2014         2                 1
#
#    Fuel type  Engine volume  Mileage  Cylinders  Gear box type  Drive wheels  \
# 0          1            3.5   186005        6.0              1             1
# 1          2            3.0   192000        6.0              2             1
# 2          2            1.3   200000        4.0              3             2
# 3          1            2.5   168966        4.0              1             1
# 4          2            1.3    91901        4.0              1             2
#
#    Doors  Wheel  Color  Airbags
# 0      1      1      1       12
# 1      1      1      2        8
# 2      1      2      2        2
# 3      1      1      3        0
# 4      1      1      1        4

# %%
df.to_csv("datasets/manipulation/result.csv")
# save dataframe to new csv file
