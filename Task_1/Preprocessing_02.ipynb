# %%
import pandas as pd 
import matplotlib.pyplot as plt 
df = pd.read_csv("datasets/manipulation/1.csv")
df.head()
# Out:
#    Unnamed: 0  Price  Levy  Manufacturer  Model  Prod. year  Category  \
# 0           0  13328  1399             1      1        2010         1
# 1           1  16621  1018             2      2        2011         1
# 2           2   8467     -             3      3        2006         2
# 3           3   3607   862             4      4        2011         1
# 4           4  11726   446             3      3        2014         2
#
#    Leather interior  Fuel type  Engine volume  Mileage  Cylinders  \
# 0                 1          1            3.5   186005        6.0
# 1                 0          2            3.0   192000        6.0
# 2                 0          2            1.3   200000        4.0
# 3                 1          1            2.5   168966        4.0
# 4                 1          2            1.3    91901        4.0
#
#    Gear box type  Drive wheels  Doors  Wheel  Color  Airbags
# 0              1             1      1      1      1       12
# ...

# %% [markdown]
# ## Process Levy so its used aswell
# => Replace "-" with 0

# %%
levy_mapping = {"-":0}
df.replace(levy_mapping,inplace=True)
df.head()
# Out:
# object

# %%
df["Levy"] = pd.to_numeric(df["Levy"],errors="coerce")
df["Levy"].dtype
df.describe()
# Out:
#          Unnamed: 0         Price          Levy  Manufacturer         Model  \
# count  17306.000000  1.730600e+04  17306.000000  17306.000000  17306.000000
# mean    9608.325263  1.744961e+04    674.369352      8.010863    143.896279
# std     5554.610524  2.006192e+05    574.680978      6.889905    262.065702
# min        0.000000  1.000000e+00      0.000000      1.000000      1.000000
# 25%     4806.250000  4.547000e+03      0.000000      5.000000      8.000000
# 50%     9573.500000  1.227650e+04    751.000000      6.000000     40.000000
# 75%    14408.750000  2.110300e+04   1017.000000      8.000000    151.000000
# max    19236.000000  2.630750e+07  11714.000000     65.000000   1590.000000
#
#          Prod. year      Category  Leather interior     Fuel type  \
# count  17306.000000  17306.000000      17306.000000  17306.000000
# mean    2011.056974      2.636889          0.740899      2.251647
# std        5.636826      1.685642          0.438154      1.137399
# ...

# %%
print(len(df.columns))
print(df.columns)
df.drop(columns=["Unnamed: 0"],inplace=True)
df.to_csv("datasets/manipulation/2.csv")
# Out:
# 17
# Index(['Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year', 'Category',
#        'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 3
#       1 print(len(df.columns))
#       2 print(df.columns)
# ----> 3 df.drop(columns=["Unnamed: 0"],inplace=True)
#       4 df.to_csv("datasets/manipulation/2.csv")
#
# File ~/dev/venvs/DL/lib/python3.12/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
# ...
