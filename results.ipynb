# %% [markdown]
# #### Run 1:
# 1.csv
# all columns except Levy. No outliers removed yet, data after A1_Preprocessing_01
# Results:
#
# MAE
# 13822.93 $
#
# MSE
# 362886400.0 $^2
#
# RMSE:
# 19049.58 $
#
# R-squared:
# -0.5
#
# Explained variance score:
# -0.24
#
# => Very bad results. More adjustments needed
#
# #### Run 2:
# 2.csv
# all columns including Levy. No outlies removed yet, data after A1_Preprocessing_02.ipynb
# Results:
#
# MAE
# 10667.49 $
#
# MSE
# 257317056.0 $^2
#
# RMSE:
# 16041.11 $
#
# R-squared:
# -0.06
#
# Explained variance score:
# -0.06
#
# => slightly better but still very bad
#
# #### Run 3:
# Manually removed outliers from Price and Levy (4 rows in total, so should not have a big effect)
# Results:
#
# MAE
# 10525.58 $
#
# MSE
# 226535120.0 $^2
#
# RMSE:
# 15051.08 $
#
# R-squared:
# 0.14
#
# Explained variance score:
# 0.14
#
# #### Run 4:
# remove color parameter (should not impact the price and may only confuse the model)
# for some reason this made it worse:
#
# MAE
# 11214.41 $
#
# MSE
# 354232896.0 $^2
#
# RMSE:
# 18821.08 $
#
# R-squared:
# -0.34
#
# Explained variance score:
# -0.33
#
# #### Run 5:
# Reduce neurons back from 128,64,32,1 to 12,32,16,1
# This brought it back down a bit:
#
# MAE
# 10881.54 $
#
# MSE
# 233709488.0 $^2
#
# RMSE:
# 15287.56 $
#
# R-squared:
# 0.11
#
# Explained variance score:
# 0.12
